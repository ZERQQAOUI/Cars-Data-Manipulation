# %% [markdown]
# Model Development
# Lets develop several models that will predict the price of the car using the variables or features. This is just an estimate but should give us an objective idea of how much the car should cost.
#
# We often use Model Development to help us predict future observations from the data we have.
#
# A Model will help us understand the exact relationship between different variables and how these variables are used to predict the result.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt   
df = pd.read_csv('clean_df.csv')
print("The first 5 rows of the dataframe") 
df = df[df['Price'] <= 5000000]
df.sort_values("Price", ascending=False).head(5)
# Out:
# The first 5 rows of the dataframe
#      Unnamed: 0     Brand          Model                Version      Price  \
# 843         843   PORSCHE       911 2013   Carrera 4S Cabriolet  1150000.0
# 842         842   PORSCHE       911 2013      Carrera Cabriolet  1150000.0
# 848         848   PORSCHE       911 2013             Carrera 4S   980000.0
# 837         837   PORSCHE   Cayenne 2018                Turbo S   980000.0
# 164         164  MERCEDES  Classe S 2014  350 d L AMG line Plus   900000.0
#
#      Modèle      Main  Kilométrage Carburant  Transmision  ...  ABS  ESP  \
# 843  2013.0  Première      29000.0   Essence  Automatique  ...  oui  oui
# 842  2013.0  Première      29000.0   Essence  Automatique  ...  oui  oui
# 848  2013.0  Première      38700.0   Essence  Automatique  ...  oui  oui
# 837  2018.0   Seconde      30000.0   Essence  Automatique  ...  oui  oui
# 164  2014.0   Seconde      69000.0    Diesel  Automatique  ...  oui  oui
#
#     Antipatinage Architecture  Cylindrée  Conso. ville Conso. route  \
# 843          oui          NaN  39.786376  56806.508876  41851.47929
# 842          oui          NaN  39.786376  56806.508876  41851.47929
# 848          oui          NaN  39.786376  56806.508876  41851.47929
# 837          oui          NaN  39.786376  56806.508876  41851.47929
# 164          oui          NaN  39.786376  56806.508876  41851.47929
#
#     Vitesse maxi. Volume du réservoir Puissance fiscale-binned
# 843    208.546729           57.662228                      Low
# 842    208.546729           57.662228                      Low
# 848    208.546729           57.662228                      Low
# 837    208.546729           57.662228                   Medium
# 164    208.546729           57.662228                      Low
#
# [5 rows x 45 columns]

# %% [markdown]
# Linear Regression and Multiple Linear Regression
# Linear Regression
# One example of a Data Model that we will be using is
#
# Simple Linear Regression.
# Simple Linear Regression is a method to help us understand the relationship between two variables:
#
# The predictor/independent variable (X)
# The response/dependent variable (that we want to predict)(Y)
# The result of Linear Regression is a linear function that predicts the response (dependent) variable as a function of the predictor (independent) variable.
#
# Linear function:
#
# a refers to the intercept of the regression line, in other words: the value of Y when X is 0
# b refers to the slope of the regression line, in other words: the value with which Y changes when X increases by 1 unit

# %%
#Lets load the modules for linear regression
from sklearn.linear_model import LinearRegression
#Create the linear regression object
lm = LinearRegression()
lm
# Out:
# LinearRegression()

# %% [markdown]
# Lets create a linear function with "Conso. route" as the predictor variable and the "price" as the response variable to see whether highway-mpg would help us to predict the car price

# %%
X = df[['Conso. route']]
Y = df['Price']
#Fit the linear model using Conso. route
lm.fit(X,Y)
# Out:
# LinearRegression()

# %% [markdown]
# We can output a prediction

# %%
Yhat=lm.predict(X)
Yhat[0:5]
# Out:
# array([135726.7805326, 135726.7805326, 135726.7805326, 135726.7805326,
#        135726.7805326])

# %% [markdown]
# Lets get the value of intercept (a) and Slope (b)

# %%
print(lm.intercept_)
print(lm.coef_)
# Out:
# 56810.87437631734
# [1.88561808]

# %% [markdown]
# Plugging in the actual values we get:
#
# price = -118898.40 +6.38 x Conso. route

# %% [markdown]
# Lets create a linear function with "Kilométrage" as the predictor variable and the "price" as the response variable to see whether Kilométrage would help us to predict the car price

# %%
lm1 = LinearRegression()
X = df[['Kilométrage']]
Y = df['Price']
lm1.fit(X,Y)
# Out:
# LinearRegression()

# %%
Yhat=lm1.predict(X)
Yhat[0:5]
# Out:
# array([135810.7329966 , 131746.22240713, 135820.62231677, 133763.64372161,
#        136631.54657063])

# %%
print(lm1.intercept_)
print(lm1.coef_)
# Out:
# 138668.74652544595
# [-0.01977864]

# %% [markdown]
# Plugging in the values ,we get
#
# Price = 151329.31802082557 - 0.02091808 x Kilométrage

# %% [markdown]
# Lets create a linear function with "Vitesse maxi." as the predictor variable and the "price" as the response variable to see whether Vitesse maxi. would help us to predict the car price

# %%
lm2 = LinearRegression()
X = df[['Vitesse maxi.']]
Y = df['Price']
lm2.fit(X,Y)
# Out:
# LinearRegression()

# %%
Yhat=lm2.predict(X)
Yhat[0:5]
# Out:
# array([135726.7805326, 135726.7805326, 135726.7805326, 135726.7805326,
#        135726.7805326])

# %%
print(lm2.intercept_)
print(lm2.coef_)
# Out:
# 35057.47279902795
# [482.71822929]

# %% [markdown]
# Plugging in the values ,we get
#
# Price = -192529.53020520025 + 1633.90944243 x Vitesse maxi.

# %% [markdown]
# Lets create a linear function with "Conso. ville" as the predictor variable and the "price" as the response variable to see whether Conso. ville would help us to predict the car price

# %%
lm3 = LinearRegression()
X = df[['Conso. ville']]
Y = df['Price']
lm3.fit(X,Y)
# Out:
# LinearRegression()

# %%
Yhat=lm3.predict(X)
Yhat[0:5]
# Out:
# array([135726.7805326, 135726.7805326, 135726.7805326, 135726.7805326,
#        135726.7805326])

# %%
print(lm3.intercept_)
print(lm3.coef_)
# Out:
# 135726.78053259873
# [0.]

# %% [markdown]
# Lets create a linear function with "Puissance fiscale" as the predictor variable and the "price" as the response variable to see whether Puissance fiscale would help us to predict the car price

# %%
lm4 = LinearRegression()
X = df[['Puissance fiscale']]
Y = df['Price']
lm4.fit(X,Y)
# Out:
# LinearRegression()

# %%
Yhat=lm4.predict(X)
Yhat[0:5]
# Out:
# array([136583.28568851, 136583.28568851, 136583.28568851, 140163.83891229,
#        140163.83891229])

# %%
print(lm4.intercept_)
print(lm4.coef_)
# Out:
# 107938.85989833613
# [3580.55322377]

# %% [markdown]
# Lets create a linear function with "Cylindrée" as the predictor variable and the "price" as the response variable to see whether  Cylindrée would help us to predict the car price

# %%
lm5 = LinearRegression()
X = df[['Cylindrée']]
Y = df['Price']
lm5.fit(X,Y)
# Out:
# LinearRegression()

# %%
Yhat=lm5.predict(X)
Yhat[0:5]
# Out:
# array([135726.7805326, 135726.7805326, 135726.7805326, 135726.7805326,
#        135726.7805326])

# %%
print(lm5.intercept_)
print(lm5.coef_)
# Out:
# 58904.344002435624
# [1930.87291716]

# %% [markdown]
# Lets create a linear function with "Modèle" as the predictor variable and the "price" as the response variable to see whether  Modèle would help us to predict the car price

# %%
lm6 = LinearRegression()
X = df[['Modèle']]
Y = df['Price']
lm6.fit(X,Y)
# Out:
# LinearRegression()

# %%
Yhat=lm6.predict(X)
Yhat[0:5]
# Out:
# array([151296.52126908,  65623.61163088, 143508.07493834,  88988.95062312,
#        151296.52126908])

# %%
print(lm6.intercept_)
print(lm6.coef_)
# Out:
# -15534634.388853393
# [7788.44633075]

# %% [markdown]
# This method is used to explain the relationship between one continuous response (dependent) variable and two or more predictor (independent) variables. Most of the real-world regression models involve multiple predictors.
#
# The equation is given by
#
# From the previous section we know that other good predictors of price could be:
#
# Puissance fiscale
# Modèle
# Vitesse maxi.
# Cylindrée
# Let's develop a model using these variables as the predictor variables.

# %%
Z = df[['Puissance fiscale', 'Modèle', 'Vitesse maxi.', 'Cylindrée']]
#Fit the linear model
lm.fit(Z, df['Price'])
# Out:
# LinearRegression()

# %%
print(lm.intercept_)
print(lm.coef_)
# Out:
# -16565202.99745396
# [4178.70006228 8012.99424183 2500.52489108  625.13122277]

# %% [markdown]
# Price = -23610945.717628386 + 3559.23277584 x Puissance fiscale + 10548.30635864 x Modèle + 11480.10411571 x Vitesse maxi. + 2870.02602893 x Cylindrée

# %% [markdown]
# Model Evaluation using Visualization
# To evaluate our models and to choose the best one? One way to do this is by using visualization.

# %%
# import the visualization package: seaborn
import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker
# %matplotlib inline

# %% [markdown]
# Regression Plot
# When it comes to simple linear regression, an excellent way to visualize the fit of our model is by using regression plots.
#
# This plot will show a combination of a scattered data points (a scatter plot), as well as the fitted linear regression line going through the data. This will give us a reasonable estimate of the relationship between the two variables, the strength of the correlation, as well as the direction (positive or negative correlation).
#
# Let's visualize Modèle as potential predictor variable of price:

# %%
width=12
height=10
plt.figure(figsize = (width,height))
#removing unecessary data
sns.regplot(x='Modèle',y='Price',data=df)

ax = plt.gca()
ax.xaxis.set_major_formatter(ticker.FormatStrFormatter('%d'))
ax.yaxis.set_major_formatter(ticker.FormatStrFormatter('%d'))
plt.ylim(0,)
# Out:
# (0.0, 1212396.655134676)

# %% [markdown]
# Let's compare this plot to the regression plot of "Kilométrage"

# %%
plt.figure(figsize=(width, height))
sns.regplot(x="Kilométrage", y="Price", data=df)

ax = plt.gca()
ax.xaxis.set_major_formatter(ticker.FormatStrFormatter('%d'))
ax.yaxis.set_major_formatter(ticker.FormatStrFormatter('%d'))
plt.ylim(0,)
# Out:
# (0.0, 1381396.1815594758)

# %% [markdown]
# Multiple Linear Regression
# Visualizing a model for Multiple Linear Regression
#
# Distribution plot : Compare the distribution of the fitted values that result from the model and distribution of the actual values.

# %%
Yhat = lm.predict(Z)
plt.figure(figsize=(width,height))
ax1=sns.distplot(df['Price'],hist=False,color="r",label="Actual Values")
sns.distplot(Yhat,hist=False,color="b",label="Fitted Values",ax=ax1)

plt.title("Actual vs Fitted Values for Price")
plt.xlabel("Price (in dh)")
plt.ylabel("Proportion of Cars")


ax = plt.gca()
ax.xaxis.set_major_formatter(ticker.FormatStrFormatter('%d'))

plt.show()
plt.close()
# Out:
# C:\Users\asus\AppData\Local\Temp\ipykernel_14328\1812842431.py:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   ax1=sns.distplot(df['Price'],hist=False,color="r",label="Actual Values")
# C:\Users\asus\AppData\Local\Temp\ipykernel_14328\1812842431.py:4: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(Yhat,hist=False,color="b",label="Fitted Values",ax=ax1)

# %% [markdown]
# We can see that the fitted values are reasonably close to the actual values, since the two distributions overlap a bit. However, there is definitely some room for improvement.

# %% [markdown]
# Polynomial Regression and Pipelines
# Polynomial regression is a particular case of the general linear regression model or multiple linear regression models.
#
# We get non-linear relationships by squaring or setting higher-order terms of the predictor variables.
#
# There are different orders of polynomial regression:
#
# Quadratic - 2nd order
# Cubic - 3rd order
# Higher order:
# A linear model did not provide the best fit while using Modèle as the predictor variable. Let's see if we can try fitting a polynomial model to the data instead.

# %%
#We will use the following function to plot the data:
def PlotPolly(model, independent_variable, dependent_variabble, Name):
    x_new = np.linspace(15, 55, 100)
    y_new = model(x_new)

    plt.plot(independent_variable, dependent_variabble, '.', x_new, y_new, '-')
    plt.title('Polynomial Fit with Matplotlib for Price ~ Kilométrage')
    ax = plt.gca()
    ax.set_facecolor((0.898, 0.898, 0.898))
    fig = plt.gcf()
    plt.xlabel(Name)
    plt.ylabel('Price of Cars')

    
    ax = plt.gca()
    ax.xaxis.set_major_formatter(ticker.FormatStrFormatter('%d'))
    ax.yaxis.set_major_formatter(ticker.FormatStrFormatter('%d'))

    plt.show()
    plt.close()

# %%
x = df['Kilométrage']
y = df['Price']
#Let's fit the polynomial using the function polyfit,then use the function to display the polynomial function.
f = np.polyfit(x, y, 3)
p = np.poly1d(f)
print(p)
# Out:
#             3            2
# -4.758e-15 x + 9.91e-08 x - 0.3263 x + 1.774e+05

# %% [markdown]
# Let's plot the function

# %%
PlotPolly(p, x, y, 'Modèle')
print(df['Modèle'])
# Out:
# 0       2014.0
# 1       2003.0
# 2       2013.0
# 3       2006.0
# 4       2014.0
#          ...
# 2175    2014.0
# 2176    2013.0
# 2177    2012.0
# 2178    2015.0
# 2179    2012.0
# Name: Modèle, Length: 2178, dtype: float64
